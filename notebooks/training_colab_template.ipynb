# %% [markdown]
# # GVI YOLO Training Template
# Upload your dataset ZIP, install GVI, then train YOLO segmentation.

# %%
# !python -m pip install -U pip
# !python -m pip install ultralytics pyyaml tqdm

# %%
# Example after uploading dataset.zip
# !unzip -q dataset.zip -d /content/dataset_root
# !yolo segment train model=yolo11n-seg.pt data=/content/dataset_root/dataset/data.yaml epochs=80 imgsz=640 batch=8
